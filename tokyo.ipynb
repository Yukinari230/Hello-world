# %% [markdown]
# <a href="https://colab.research.google.com/github/Yukinari230/Hello-world/blob/master/tokyo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
plt.figure(figsize=(4,3),dpi=180)
objects = ('Mar',' ','',' ','','23 ','',' ','','',
           '28',' ','','', 'A', '', '', '','','',
           '7','','','','11','','','','15','','','','','20','','','','','25','','','','','',
           'May','','','','','6','','','','10','','','','','15','','','','','20','','','','',
           '','25','','','','','','Jul','','','','','','7','','','','','','','','','16','',
           '','','','','','','','','','','','','','Jl',' ','','','','','','','','10','','','','','','16')
y_pos = np.arange(len(objects))
performance = [9,7,11,7,2,16,17,41,47,40,63,68,13,78,66,90,89,120,143,83,80,144,181,185,
               197,166,91,161,127,149,201,181,107,102,107,132,134,161,103,72,39,112,47,
               46,165,160,91,87,58,38,23,39,36,22,15,28,10,30,9,14,5,10,5,5,11,3,2,14,8,
               10,11,15,22,14,5,13,34,12,28,20,26,14,13,12,18,22,25,24,47,48,27,16,41,
               35,39,35,29,31,55,48,54,57,60,58,54,67,107,124,131,111,102,106,75,224,243,206,206,119,143,165,286]
plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('Cases')
plt.title('Cases in Tokyo Jul 16th')
plt.show()
